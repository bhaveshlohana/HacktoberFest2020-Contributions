# %% [markdown]
# # Support Vector Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Data Loading

# %%
PATH = "../../../Regression/Support_Vector_Regression/Python/Position_Salaries.csv"

# %%
dataset = pd.read_csv(PATH)

# %%
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Feature Scaling

# %%
y = y.reshape(len(y), 1)

# %%
from sklearn.preprocessing import StandardScaler

sc_X = StandardScaler()
X = sc_X.fit_transform(X)

sc_y = StandardScaler()
y = sc_y.fit_transform(y)

# %% [markdown]
# ## Model

# %%
from sklearn.svm import SVR

regressor = SVR(kernel='rbf')
regressor.fit(X, y)
# Out:
# /home/pritthijit/Online-Courses/Machine-Learning/Course/Python/venv/lib/python3.6/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVR()

# %% [markdown]
# ## Prediction

# %%
sample = [[6.5]]
sc_y.inverse_transform(regressor.predict(sc_X.transform(sample)))
# Out:
# array([170370.0204065])

# %% [markdown]
# ## Visualization

# %%
y_pred = sc_y.inverse_transform(regressor.predict(X))

X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
plt.figure(figsize=(12, 8))
plt.scatter(X, y, color='red')
plt.plot(X, y_pred, color='blue')
plt.title("Truth or Bluff (Support Vector Regression)")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ### Higher Resolution

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid)))

# %%
plt.figure(figsize=(12, 8))
plt.scatter(X, y, color='red')
plt.plot(X_grid, y_pred, color='blue')
plt.title("Truth or Bluff (Support Vector Regression)")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()
