# %% [markdown]
# # Polynomial Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Data Loading

# %%
PATH = "../../../Regression/Polynomial_Regression/Python/Position_Salaries.csv"

# %%
dataset = pd.read_csv(PATH)

# %%
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualisation

# %%
plt.figure(figsize=(12, 8))
plt.scatter(X, y, color='red')
plt.plot(X, lin_reg.predict(X), color='blue')
plt.title("Truth or Bluff (Linear Regression)")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.scatter(X, y, color='red')
plt.plot(X, lin_reg_2.predict(X_poly), color='blue')
plt.title("Truth or Bluff (Polynomial Regression)")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Predictions

# %%
sample = [[6.5]]
print("Linear Regression: ", lin_reg.predict(sample)[0])
print("Polynomial Regression: ", lin_reg_2.predict(poly_reg.fit_transform(sample))[0])
# Out:
# Linear Regression:  330378.78787878784
# Polynomial Regression:  158862.45265154913
