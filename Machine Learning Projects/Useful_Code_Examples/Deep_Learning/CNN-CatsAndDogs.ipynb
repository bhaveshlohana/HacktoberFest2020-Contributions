# %% [markdown]
# # Convolution Neural Networks

# %% [markdown]
# #### Cats and Dogs

# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Image Data Generator Class

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Training Set

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

training_set = train_datagen.flow_from_directory(
        '../../../Deep_Learning/CNN/dataset/training_set',
        target_size=(128, 128),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Test Set

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_set = test_datagen.flow_from_directory(
        '../../../Deep_Learning/CNN/dataset/test_set',
        target_size=(128, 128),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Model Building

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten

# %%
tf.random.set_seed(42)

cnn = Sequential()

cnn.add(Conv2D(32, kernel_size=(3, 3), input_shape=(128, 128, 3), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2, 2)))
cnn.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2, 2)))
cnn.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2, 2)))

cnn.add(Flatten())
cnn.add(Dense(64, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(1, activation='sigmoid'))

cnn.compile(loss='binary_crossentropy', optimizer='adam',
            metrics=['accuracy'])

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                802880
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 831,585
# Trainable params: 831,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Part 3 - Model Training

# %%
epochs = 100

cnn.fit_generator(training_set, validation_data=test_set, 
                  epochs=epochs)
# Out:
# WARNING:tensorflow:From <ipython-input-9-5ebb087b086f>:4: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 250 steps, validate for 63 steps
# Epoch 1/100
# 250/250 [==============================] - 34s 137ms/step - loss: 0.6904 - accuracy: 0.5250 - val_loss: 0.6699 - val_accuracy: 0.5890
# Epoch 2/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.6292 - accuracy: 0.6503 - val_loss: 0.5709 - val_accuracy: 0.7130
# Epoch 3/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.5734 - accuracy: 0.7013 - val_loss: 0.5606 - val_accuracy: 0.7270
# Epoch 4/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.5311 - accuracy: 0.7352 - val_loss: 0.5268 - val_accuracy: 0.7425
# Epoch 5/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.5104 - accuracy: 0.7440 - val_loss: 0.4942 - val_accuracy: 0.7680
# Epoch 6/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.4814 - accuracy: 0.7729 - val_loss: 0.4458 - val_accuracy: 0.8120
# Epoch 7/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.4561 - accuracy: 0.7885 - val_loss: 0.4370 - val_accuracy: 0.8065
# Epoch 8/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.4448 - accuracy: 0.7985 - val_loss: 0.4373 - val_accuracy: 0.8060
# Epoch 9/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.4300 - accuracy: 0.8025 - val_loss: 0.4602 - val_accuracy: 0.7940
# Epoch 10/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.4095 - accuracy: 0.8108 - val_loss: 0.3928 - val_accuracy: 0.8325
# Epoch 11/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.4094 - accuracy: 0.8169 - val_loss: 0.4084 - val_accuracy: 0.8290
# Epoch 12/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.3890 - accuracy: 0.8257 - val_loss: 0.4102 - val_accuracy: 0.8200
# Epoch 13/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.3778 - accuracy: 0.8350 - val_loss: 0.3616 - val_accuracy: 0.8465
# Epoch 14/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.3767 - accuracy: 0.8336 - val_loss: 0.3639 - val_accuracy: 0.8465
# Epoch 15/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.3535 - accuracy: 0.8450 - val_loss: 0.3981 - val_accuracy: 0.8305
# Epoch 16/100
# 250/250 [==============================] - 34s 134ms/step - loss: 0.3521 - accuracy: 0.8469 - val_loss: 0.4308 - val_accuracy: 0.8140
# Epoch 17/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.3374 - accuracy: 0.8529 - val_loss: 0.3854 - val_accuracy: 0.8380
# Epoch 18/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.3331 - accuracy: 0.8537 - val_loss: 0.4038 - val_accuracy: 0.8280
# Epoch 19/100
# 250/250 [==============================] - 34s 134ms/step - loss: 0.3277 - accuracy: 0.8577 - val_loss: 0.3601 - val_accuracy: 0.8515
# Epoch 20/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.3154 - accuracy: 0.8635 - val_loss: 0.3843 - val_accuracy: 0.8455
# Epoch 21/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.3179 - accuracy: 0.8572 - val_loss: 0.3602 - val_accuracy: 0.8530
# Epoch 22/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2920 - accuracy: 0.8749 - val_loss: 0.3609 - val_accuracy: 0.8505
# Epoch 23/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2949 - accuracy: 0.8700 - val_loss: 0.3766 - val_accuracy: 0.8395
# Epoch 24/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2945 - accuracy: 0.8770 - val_loss: 0.3661 - val_accuracy: 0.8485
# Epoch 25/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2827 - accuracy: 0.8815 - val_loss: 0.3423 - val_accuracy: 0.8655
# Epoch 26/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2740 - accuracy: 0.8813 - val_loss: 0.3344 - val_accuracy: 0.8620
# Epoch 27/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2699 - accuracy: 0.8821 - val_loss: 0.4002 - val_accuracy: 0.8345
# Epoch 28/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2536 - accuracy: 0.8915 - val_loss: 0.3719 - val_accuracy: 0.8550
# Epoch 29/100
# 250/250 [==============================] - 34s 134ms/step - loss: 0.2568 - accuracy: 0.8920 - val_loss: 0.3599 - val_accuracy: 0.8625
# Epoch 30/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2553 - accuracy: 0.8930 - val_loss: 0.3490 - val_accuracy: 0.8640
# Epoch 31/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2461 - accuracy: 0.8969 - val_loss: 0.3465 - val_accuracy: 0.8580
# Epoch 32/100
# 250/250 [==============================] - 34s 134ms/step - loss: 0.2430 - accuracy: 0.8972 - val_loss: 0.3387 - val_accuracy: 0.8575
# Epoch 33/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2406 - accuracy: 0.9007 - val_loss: 0.4002 - val_accuracy: 0.8515
# Epoch 34/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2323 - accuracy: 0.9006 - val_loss: 0.4125 - val_accuracy: 0.8565
# Epoch 35/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2217 - accuracy: 0.9047 - val_loss: 0.4084 - val_accuracy: 0.8535
# Epoch 36/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2421 - accuracy: 0.8967 - val_loss: 0.3452 - val_accuracy: 0.8635
# Epoch 37/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2208 - accuracy: 0.9095 - val_loss: 0.3519 - val_accuracy: 0.8715
# Epoch 38/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2142 - accuracy: 0.9131 - val_loss: 0.4009 - val_accuracy: 0.8645
# Epoch 39/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2074 - accuracy: 0.9137 - val_loss: 0.3882 - val_accuracy: 0.8620
# Epoch 40/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1990 - accuracy: 0.9181 - val_loss: 0.4756 - val_accuracy: 0.8450
# Epoch 41/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2011 - accuracy: 0.9178 - val_loss: 0.3939 - val_accuracy: 0.8695
# Epoch 42/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2010 - accuracy: 0.9150 - val_loss: 0.4770 - val_accuracy: 0.8495
# Epoch 43/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1970 - accuracy: 0.9195 - val_loss: 0.3935 - val_accuracy: 0.8610
# Epoch 44/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1979 - accuracy: 0.9170 - val_loss: 0.4863 - val_accuracy: 0.8470
# Epoch 45/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2088 - accuracy: 0.9162 - val_loss: 0.4098 - val_accuracy: 0.8560
# Epoch 46/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1931 - accuracy: 0.9197 - val_loss: 0.4365 - val_accuracy: 0.8585
# Epoch 47/100
# 250/250 [==============================] - 34s 134ms/step - loss: 0.1917 - accuracy: 0.9230 - val_loss: 0.3861 - val_accuracy: 0.8720
# Epoch 48/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1843 - accuracy: 0.9225 - val_loss: 0.3672 - val_accuracy: 0.8680
# Epoch 49/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1859 - accuracy: 0.9211 - val_loss: 0.3740 - val_accuracy: 0.8770
# Epoch 50/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1866 - accuracy: 0.9225 - val_loss: 0.4141 - val_accuracy: 0.8630
# Epoch 51/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1793 - accuracy: 0.9285 - val_loss: 0.3890 - val_accuracy: 0.8750
# Epoch 52/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1757 - accuracy: 0.9283 - val_loss: 0.4038 - val_accuracy: 0.8660
# Epoch 53/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1671 - accuracy: 0.9325 - val_loss: 0.4018 - val_accuracy: 0.8720
# Epoch 54/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1653 - accuracy: 0.9295 - val_loss: 0.4992 - val_accuracy: 0.8660
# Epoch 55/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1679 - accuracy: 0.9309 - val_loss: 0.4989 - val_accuracy: 0.8655
# Epoch 56/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1691 - accuracy: 0.9321 - val_loss: 0.5650 - val_accuracy: 0.8365
# Epoch 57/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1701 - accuracy: 0.9319 - val_loss: 0.4629 - val_accuracy: 0.8590
# Epoch 58/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1685 - accuracy: 0.9301 - val_loss: 0.4206 - val_accuracy: 0.8730
# Epoch 59/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1655 - accuracy: 0.9325 - val_loss: 0.4171 - val_accuracy: 0.8765
# Epoch 60/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1608 - accuracy: 0.9351 - val_loss: 0.3944 - val_accuracy: 0.8735
# Epoch 61/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1627 - accuracy: 0.9348 - val_loss: 0.4009 - val_accuracy: 0.8680
# Epoch 62/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1583 - accuracy: 0.9354 - val_loss: 0.3872 - val_accuracy: 0.8745
# Epoch 63/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1535 - accuracy: 0.9385 - val_loss: 0.4896 - val_accuracy: 0.8575
# Epoch 64/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1598 - accuracy: 0.9362 - val_loss: 0.4088 - val_accuracy: 0.8760
# Epoch 65/100
# 250/250 [==============================] - 34s 134ms/step - loss: 0.1561 - accuracy: 0.9371 - val_loss: 0.5366 - val_accuracy: 0.8450
# Epoch 66/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1598 - accuracy: 0.9361 - val_loss: 0.4458 - val_accuracy: 0.8495
# Epoch 67/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1540 - accuracy: 0.9388 - val_loss: 0.4631 - val_accuracy: 0.8690
# Epoch 68/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1459 - accuracy: 0.9386 - val_loss: 0.5254 - val_accuracy: 0.8520
# Epoch 69/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1483 - accuracy: 0.9411 - val_loss: 0.4527 - val_accuracy: 0.8690
# Epoch 70/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1426 - accuracy: 0.9452 - val_loss: 0.4307 - val_accuracy: 0.8775
# Epoch 71/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1340 - accuracy: 0.9459 - val_loss: 0.4458 - val_accuracy: 0.8820
# Epoch 72/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1360 - accuracy: 0.9450 - val_loss: 0.4260 - val_accuracy: 0.8865
# Epoch 73/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1337 - accuracy: 0.9469 - val_loss: 0.4267 - val_accuracy: 0.8835
# Epoch 74/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1398 - accuracy: 0.9409 - val_loss: 0.4618 - val_accuracy: 0.8700
# Epoch 75/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1393 - accuracy: 0.9438 - val_loss: 0.5033 - val_accuracy: 0.8615
# Epoch 76/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1413 - accuracy: 0.9440 - val_loss: 0.4946 - val_accuracy: 0.8780
# Epoch 77/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1391 - accuracy: 0.9442 - val_loss: 0.4332 - val_accuracy: 0.8790
# Epoch 78/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1333 - accuracy: 0.9477 - val_loss: 0.5063 - val_accuracy: 0.8725
# Epoch 79/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1333 - accuracy: 0.9446 - val_loss: 0.4598 - val_accuracy: 0.8815
# Epoch 80/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1247 - accuracy: 0.9523 - val_loss: 0.4805 - val_accuracy: 0.8680
# Epoch 81/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1335 - accuracy: 0.9495 - val_loss: 0.4543 - val_accuracy: 0.8770
# Epoch 82/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1237 - accuracy: 0.9511 - val_loss: 0.4778 - val_accuracy: 0.8795
# Epoch 83/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1238 - accuracy: 0.9504 - val_loss: 0.5147 - val_accuracy: 0.8700
# Epoch 84/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1261 - accuracy: 0.9501 - val_loss: 0.5904 - val_accuracy: 0.8665
# Epoch 85/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1118 - accuracy: 0.9559 - val_loss: 0.5300 - val_accuracy: 0.8600
# Epoch 86/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1320 - accuracy: 0.9479 - val_loss: 0.4678 - val_accuracy: 0.8805
# Epoch 87/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1234 - accuracy: 0.9514 - val_loss: 0.4935 - val_accuracy: 0.8745
# Epoch 88/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1236 - accuracy: 0.9523 - val_loss: 0.5035 - val_accuracy: 0.8775
# Epoch 89/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1241 - accuracy: 0.9506 - val_loss: 0.5126 - val_accuracy: 0.8770
# Epoch 90/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1190 - accuracy: 0.9526 - val_loss: 0.4680 - val_accuracy: 0.8790
# Epoch 91/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1144 - accuracy: 0.9515 - val_loss: 0.5190 - val_accuracy: 0.8770
# Epoch 92/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1242 - accuracy: 0.9506 - val_loss: 0.5110 - val_accuracy: 0.8855
# Epoch 93/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1318 - accuracy: 0.9454 - val_loss: 0.5290 - val_accuracy: 0.8735
# Epoch 94/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1157 - accuracy: 0.9531 - val_loss: 0.4698 - val_accuracy: 0.8755
# Epoch 95/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1227 - accuracy: 0.9530 - val_loss: 0.6250 - val_accuracy: 0.8545
# Epoch 96/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1153 - accuracy: 0.9529 - val_loss: 0.4219 - val_accuracy: 0.8900
# Epoch 97/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1151 - accuracy: 0.9554 - val_loss: 0.4913 - val_accuracy: 0.8790
# Epoch 98/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1104 - accuracy: 0.9566 - val_loss: 0.5495 - val_accuracy: 0.8840
# Epoch 99/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1148 - accuracy: 0.9546 - val_loss: 0.5341 - val_accuracy: 0.8730
# Epoch 100/100
# 250/250 [==============================] - 34s 135ms/step - loss: 0.1175 - accuracy: 0.9565 - val_loss: 0.5049 - val_accuracy: 0.8785

# %% [markdown]
# ## Part 4 - Model Evaluation

# %%
metrics = pd.DataFrame(cnn.history.history)
metrics[['loss', 'val_loss']].plot()
metrics[['accuracy', 'val_accuracy']].plot()

# %%
from tensorflow.keras.preprocessing import image
from matplotlib.image import imread
import matplotlib.pyplot as plt

PATH = '../../../Deep_Learning/CNN/dataset/single_prediction/cat_or_dog_1.jpg'

test_image = image.load_img(PATH, target_size=(128, 128))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image / 255, axis=0)
result = cnn.predict_classes(test_image)
label = list(training_set.class_indices.keys())[result[0][0]]

plt.title("Prediction: " + label)
plt.imshow(imread(PATH))

# %%
cnn.save("cat_dog.h5")

# %%
from tensorflow.keras.preprocessing import image
from matplotlib.image import imread
import matplotlib.pyplot as plt

PATH = '../../../Deep_Learning/CNN/dataset/single_prediction/cat_or_dog_2.jpg'

test_image = image.load_img(PATH, target_size=(128, 128))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image / 255, axis=0)
result = cnn.predict_classes(test_image)
label = list(training_set.class_indices.keys())[result[0][0]]

plt.title("Prediction: " + label)
plt.imshow(imread(PATH))
